# %% [markdown]
# <center> <h1> Técnicas para el manejo de datos en Python </h1>
#
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTncB2fp8FCRjubfKXk8Hvl_NA8ycwu2BmHwQ&usqp=CAU)
#
# </center>
#
#
#
#
# Expositor: Katherine Morales
#
# - Linkedin [in/katherine-morales-7194a3108/](https://www.linkedin.com/in/katherine-morales-7194a3108/)

# %% [markdown]
# # Listas
# ---

# %%
# lista vacia
lista = []

# lista de enteros
lista = [1, 2, 3]

# lista de diferentes tipos de datos
lista = [1, "Curso Python", 3.4]

# %%
# Indexacion de listas

lista = ['p', 'y', 't', 'h', 'o', 'n']

# Output: ?
print(lista[0])

# Output: ?
print(lista[2])

# Output: ?
print(lista[4])
# Out:
# p
# t
# o

# %%
print(lista[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-b57f4761bb07> in <module>()
# ----> 1 print(lista[6])
#
# IndexError: list index out of range

# %%
lista = ['p', 'y', 't', 'h', 'o', 'n']

print(lista[-1])
print(lista[-2])
# Out:
# n
# o

# %%
lista = ['p', 'y', 't', 'h', 'o', 'n']

print(lista[:4])
print(lista[4:])
print(lista[:])
print(lista[:-4])
# Out:
# ['p', 'y', 't', 'h']
# ['o', 'n']
# ['p', 'y', 't', 'h', 'o', 'n']
# ['p', 'y']

# %%
l1 = [1, 2]
l2 = ['a', 'b']
l1.append(3)
print('l1 append', l1)
print('l1+l2', l1+l2)
print('l2 *2', l2*2)
l2.insert(0, 'z')  
print('l2 insert',l2  )
l2[0:0] = [ 'x', 'y', 'w']
print('l2 insert',l2  )
# Out:
# l1 append [1, 2, 3]
# l1+l2 [1, 2, 3, 'a', 'b']
# l2 *2 ['a', 'b', 'a', 'b']
# l2 insert ['z', 'a', 'b']
# l2 insert ['x', 'y', 'w', 'z', 'a', 'b']

# %%
for nombre in ['Tania','Roberto','Juan']:
    print("Mi nombre es ", nombre)
# Out:
# Mi nombre es  Tania
# Mi nombre es  Roberto
# Mi nombre es  Juan

# %%
nombres = ['Tania','Roberto','Juan']
i = 0
while i < len(nombres):
  print(nombres[i])
  i = i + 1
# Out:
# Tania
# Roberto
# Juan

# %%
[nombre+' SEE' for nombre in nombres]
# Out:
# ['Tania SEE', 'Roberto SEE', 'Juan SEE']

# %%
for i, nombre in enumerate(nombres):
    print (i, ",",nombre)
# Out:
# 0 , Tania
# 1 , Roberto
# 2 , Juan

# %% [markdown]
# # Pilas
#
# ## Usando listas

# %%
pila = []
print(pila)
print('Push')
pila.append('1') # push
print(pila)
pila.append('2')
print(pila)
pila.append('3')
print(pila)
print('Pop')
pila.pop()
print(pila)
pila.pop()
print(pila)
pila.pop()
print(pila)
# Out:
# []
# Push
# ['1']
# ['1', '2']
# ['1', '2', '3']
# Pop
# ['1', '2']
# ['1']
# []

# %% [markdown]
# # Diccionarios

# %%
mi_dict = {"nombre": "Katherine", "edad":27, "ciudad": "Paris"}
print(mi_dict)

# o utilizar el constructor dict, nota: no son necesarias las comillas para las claves
mi_dict_2 = dict(nombre="Juan", edad=27, ciudad="Quito")
print(mi_dict_2)
# Out:
# {'nombre': 'Katherine', 'edad': 27, 'ciudad': 'Paris'}
# {'nombre': 'Juan', 'edad': 27, 'ciudad': 'Quito'}

# %%
mi_dict = {"nombre": "Katherine", "edad":27, "ciudad": ["Paris", 'Quito']}
nombre_en_dicto = mi_dict["ciudad"]
print(nombre_en_dicto)
print(nombre_en_dicto[0])
# KeyError si no se encuentra ninguna clave
print(mi_dict["apellido"])
# Out:
# ['Paris', 'Quito']
# Paris
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-0da7a7b7a21f> in <module>()
#       4 print(nombre_en_dicto[0])
#       5 # KeyError si no se encuentra ninguna clave
# ----> 6 print(mi_dict["apellido"])
#
# KeyError: 'apellido'

# %%
# Añadir y modificar elementos
# añadir una nueva clave
mi_dict["email"] = "katy@yahoo.com"
print(mi_dict)

# o sobrescribir la clave ya existente
mi_dict["email"] = "otrakaty@yahoo.com"
print(mi_dict)

# borrar un par clave-valor
del mi_dict["email"]

# esto devuelve el valor y elimina el par clave-valor
print("valor extraído:", mi_dict.pop("edad"))
print(mi_dict)

# devuelve y elimina el último par clave-valor insertado 
print("elemento pop:", mi_dict.popitem())
print(mi_dict)

# clear() : elimina todos los pares
# mi_dict.clear()
# Out:
# {'nombre': 'Katherine', 'edad': 27, 'ciudad': ['Paris', 'Quito'], 'email': 'katy@yahoo.com'}
# {'nombre': 'Katherine', 'edad': 27, 'ciudad': ['Paris', 'Quito'], 'email': 'otrakaty@yahoo.com'}
# valor extraído: 27
# {'nombre': 'Katherine', 'ciudad': ['Paris', 'Quito']}
# elemento pop: ('ciudad', ['Paris', 'Quito'])
# {'nombre': 'Katherine'}

# %%
# Usa el método update() para fusionar 2 dicts
# Las claves existentes se sobrescriben, las nuevas se añaden
mi_dict = {"nombre": "Max", "edad":28, "email": "max@xyz.com"}
mi_dict_2 = dict(nombre="Lisa", age=27, city="Boston")

mi_dict.update(mi_dict_2)
print(mi_dict)
# Out:
# {'nombre': 'Lisa', 'edad': 28, 'email': 'max@xyz.com', 'age': 27, 'city': 'Boston'}

# %% [markdown]
# # ZIP

# %%
x = ("Joey", "Monica", "Ross")
y = ("Chandler", "Pheobe")
z = ("Katherine", "Tania", "Tatiana")

resultado = zip(x, y, z)

print(result)
print(tuple(resultado))
# Out:
# <zip object at 0x7f2aa0d19cd0>
# (('Joey', 'Chandler', 'Katherine'), ('Monica', 'Pheobe', 'Tania'))

# %%
# Aqui utilizamos la función zip con las listas y luego la función dic() para convertirlas en un diccionario:
moneda = ['dolar', 'euro', 'peso', 'lira']
codigo = ['DL', 'ER', 'PE', 'LI']
dict(zip(moneda, codigo))
# Out:
# {'dolar': 'DL', 'euro': 'ER', 'lira': 'LI', 'peso': 'PE'}
